# %%
import pandas as pd
df=pd.read_csv("C://Users//sinci//Downloads//sales.csv")

# %%
import matplotlib.pyplot as plt
df=plt.hist(df['Amount Sold'])
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

col_to_plot = ['Amount Sold']
data_to_plot = [df[col].values for col in col_to_plot]  

plt.boxplot(data_to_plot, labels=col_to_plot)
plt.xlabel('Categories')
plt.ylabel('Amount Sold')
plt.title('Box Plot of Amount Sold')
plt.show()

# %%
sns.kdeplot(df['Amount Sold'])  
plt.xlabel('Amount Sold')
plt.ylabel('Density')
plt.title('Density Plot of Amount Sold')
plt.show()
